# %% [markdown]
# # FaceGuard Siamese Training Demo
#
# Replace placeholder paths with authorized images and a validation-derived threshold.

# %%
# !pip install -e .

# %%
print("Prepare data/siamese/{anchor,positive,negative}/<identity>/*.jpg before training.")

# %%
# !python scripts/train_siamese.py --anchor-root data/siamese/anchor --positive-root data/siamese/positive --negative-root data/siamese/negative --checkpoint models/face_verification_model.pth --epochs 15 --batch-size 16
